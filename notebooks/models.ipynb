# %% [markdown]
# ## Loading the dataset

# %%
import pandas as pd 

movies = pd.read_csv('../data/ml-32m/movies.csv')
ratings = pd.read_csv('../data/ml-32m/ratings.csv')
tags = pd.read_csv('../data/ml-32m/tags.csv')

merged = pd.merge(movies , ratings , on = 'movieId')
merged.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0      10     2.5  1169265231
# 1      11     3.0   850085076
# 2      17     4.0  1027305751
# 3      19     3.0   974704488
# 4      20     5.0  1553184230

# %% [markdown]
# ## SVD model

# %%
import joblib
import os

# %%
def svd_model(df , model_path = 'svd_model.pkl'):
    if os.path.exists(model_path):
        model = joblib.load(model_path)
        print('Model loaded and ready.')
    else:
        print('Model not found. Training a new one...')
        from surprise import Dataset, Reader
        from surprise import SVD
        from surprise.model_selection import train_test_split
        from surprise import accuracy
        
        reader = Reader(rating_scale=(0, 5))  
        data = Dataset.load_from_df(df[['userId', 'title', 'rating']], reader)
        
        trainset, testset = train_test_split(data, test_size=0.2)
        
        model = SVD()
        model.fit(trainset)
        
        predictions = model.test(testset)
        
        rmse = accuracy.rmse(predictions)
        print(f'RMSE: {rmse}')
        joblib.dump(model, 'svd_model.pkl')

    return model

# %% [markdown]
# ## Recommend with this model

# %%
def recommend (df , model , user_id):
    movies = df['title'].unique()
    movie_watched = df[df['userId'] == user_id].title.values
    new_movies = [movie for movie in movies if movie not in movie_watched]
    predictions = {}
    for movie in new_movies:
        predict = model.predict (user_id , movie).est
        predictions [movie] = predict.round(2)
    sorted_movies = sorted(predictions.items(), key=lambda x: x[1], reverse=True)
    return sorted_movies

# %%
# %%time
model = svd_model (merged)

# %%
# %%time
recommend (merged , model , 674)
# Out:
# CPU times: total: 5.81 s
# Wall time: 5.83 s
# [('Memories of Matsuko (Kiraware Matsuko no isshô) (2006)', 3.43),
#  ('Connections (1978)', 3.38),
#  ('La Soufrière - Warten auf eine unausweichliche Katastrophe (1977)', 3.31),
#  ('Organizer, The (I compagni) (1963)', 3.26),
#  ('Alone in the Wilderness (2004)', 3.24),
#  ('How to Steal a Million (1966)', 3.23),
#  ('North & South (2004)', 3.22),
#  ('Meet Me in St. Louis (1944)', 3.21),
#  ('Top Gun: Maverick (2022)', 3.21),
#  ('Mike Birbiglia: What I Should Have Said Was Nothing (2008)', 3.19),
#  ('House Is Black, The (1963)', 3.18),
#  ('Drishyam (2015)', 3.18),
#  ('Sorrow and the Pity, The (Le chagrin et la pitié) (1969)', 3.16),
#  ('Animals are Beautiful People (1974)', 3.15),
#  ('Fishing with John (1991)', 3.15),
#  ('Mission: Impossible - Fallout (2018)', 3.14),
#  ('Long Way Round (2004)', 3.13),
#  ('Die Hard (1988)', 3.12),
#  ('Newsies (1992)', 3.12),
#  ('The Adventures of Sherlock Holmes and Dr. Watson: The Hound of the Baskervilles (1981)',
#   3.12),
#  ('Sherlock: The Blind Banker', 3.12),
#  ('Few Good Men, A (1992)', 3.11),
#  ('Pride & Prejudice (2005)', 3.11),
#  ("Don't Look Now: We're Being Shot At (La grande vadrouille) (1966)", 3.11),
#  ('Wodaabe: Herdsmen of the Sun (1989)', 3.11),
#  ('Hope (2013)', 3.11),
#  ('Sisters of the Gion (Gion no shimai) (1936)', 3.1),
#  ('Great White Silence, The (1924)', 3.1),
#  ('Streetwise (1984)', 3.1),
#  ('Band of Brothers (2001)', 3.1),
#  ('I Am So Proud of You (2008)', 3.1),
#  ('My Man Godfrey (1957)', 3.09),
#  ('Watch Out for the Automobile (Beregis avtomobilya) (1966)', 3.08),
#  ('Dunce Class on Vacation, The (Hababam sinifi tatilde) (1978)', 3.08),
#  ('After Lucia (2012)', 3.08),
#  ('13 Hours (2016)', 3.08),
#  ('Fugitive, The (1993)', 3.07),
#  ('Paperman (2012)', 3.07),
#  ('Drishyam (2013)', 3.07),
#  ('Planet Earth (2006)', 3.07),
#  ('Dangal (2016)', 3.07),
#  ('Apollo 13 (1995)', 3.06),
#  ('Thin Man Goes Home, The (1945)', 3.06),
#  ('Undefeated (2011)', 3.06),
#  ('Romantics Anonymous (Les émotifs anonymes) (2010)', 3.06),
#  ('The Butterfly Circus (2009)', 3.06),
#  ('Pollyanna (2003)', 3.06),
#  ('Rabbit of Seville (1950)', 3.06),
#  ('Lion King, The (1994)', 3.05),
#  ('Beauty and the Beast (1991)', 3.05),
#  ('Tokyo Twilight (Tôkyô boshoku) (1957)', 3.05),
#  ('Wings of Hope (Julianes Sturz in den Dschungel) (2000)', 3.05),
#  ('Travelling Players, The (O thiasos) (1975)', 3.05),
#  ('Instructions Not Included (No se Aceptan Devoluciones) (2013)', 3.05),
#  ('I, Claudius (1976)', 3.05),
#  ('Twelve Angry Men (1954)', 3.05),
#  ('The Mole (2020)', 3.05),
#  ('Violet Evergarden: The Movie (2020)', 3.05),
#  ('Winnie the Pooh and the Blustery Day (1968)', 3.04),
#  ('Big City, The (Mahanagar) (1963)', 3.04),
#  ('The Work of Director Chris Cunningham (2003)', 3.04),
#  ('Attack On Titan (2013)', 3.04),
#  ('Hunt for Red October, The (1990)', 3.03),
#  ('Black Book (Zwartboek) (2006)', 3.03),
#  ('Intouchables (2011)', 3.03),
#  ('Bitter Lake (2015)', 3.03),
#  ('Clock Cleaners (1937)', 3.03),
#  ('Pride and Prejudice (1995)', 3.02),
#  ('Heimat - A Chronicle of Germany (Heimat - Eine deutsche Chronik) (1984)',
#   3.02),
#  ('Persuasion (2007)', 3.02),
#  ('Adrift in Tokyo (Tenten) (2007)', 3.02),
#  ('Bo Burnham: Words, Words, Words (2010)', 3.02),
#  ("Mickey's Trailer (1938)", 3.02),
#  ('Hidden Figures (2016)', 3.02),
#  ('Coco (2017)', 3.02),
#  ("Can't Get You Out of My Head: An Emotional History of the Modern World (2021)",
#   3.02),
#  ('All That Heaven Allows (1955)', 3.01),
#  ("Ocean's Eleven (2001)", 3.01),
#  ('Mostly Martha (Bella Martha) (2001)', 3.01),
#  ('Before the Fall (NaPolA - Elite für den Führer) (2004)', 3.01),
#  ('Best Intentions, The (Den goda viljan) (1992)', 3.01),
#  ('Olympia Part One: Festival of the Nations (Olympia 1. Teil - Fest der Völker) (1938)',
#   3.01),
#  ('Report on the Party and the Guests, A (O slavnosti a hostech) (1966)',
#   3.01),
#  ('Century of the Self, The (2002)', 3.01),
#  ("Winter on Fire: Ukraine's Fight for Freedom (2015)", 3.01),
#  ('Long Way Down (2010)', 3.01),
#  ('The Work (2017)', 3.01),
#  ('Mushishi: The Shadow That Devours the Sun (2014)', 3.01),
#  ('Charade (1963)', 3.0),
#  ('Shadow of the Thin Man (1941)', 3.0),
#  ('Welcome Mr. Marshall (Bienvenido Mister Marshall) (1953)', 3.0),
#  ('Rush: Beyond the Lighted Stage (2010)', 3.0),
#  ('New York: A Documentary Film (1999)', 3.0),
#  ('McFarland, USA (2015)', 3.0),
#  ('Elephant (1989)', 3.0),
#  ('While You Were Fighting: A Thor Mockumentary (2016)', 3.0),
#  ('Moana (2016)', 3.0),
#  ('Chasing Coral (2017)', 3.0),
#  ('Muppet Christmas Carol, The (1992)', 2.99),
#  ('The Count of Monte Cristo (2002)', 2.99),
#  ("Who's Singin' Over There? (a.k.a. Who Sings Over There) (Ko to tamo peva) (1980)",
#   2.99),
#  ('Holiday (1938)', 2.99),
#  ('Gentleman Jim (1942)', 2.99),
#  ('When a Woman Ascends the Stairs (Onna ga kaidan wo agaru toki) (1960)',
#   2.99),
#  ('Enron: The Smartest Guys in the Room (2005)', 2.99),
#  ('Seven Up! (1964)', 2.99),
#  ('Like Stars on Earth (Taare Zameen Par) (2007)', 2.99),
#  ('Business of Being Born, The (2008)', 2.99),
#  ('Year of the Hare, The (Jäniksen vuosi) (1977)', 2.99),
#  ('The Count of Monte Cristo (1998)', 2.99),
#  ('Only Old Men Are Going to Battle (V boy idut odni stariki) (1973)', 2.99),
#  ('Tomorrow (2015)', 2.99),
#  ('Rabbit Seasoning (1952)', 2.99),
#  ('Thelonious Monk: Straight, No Chaser (1988)', 2.99),
#  ('In a Heartbeat (2017)', 2.99),
#  ('I Want to Eat Your Pancreas (2018)', 2.99),
#  ('Doctor Who: The Day of the Doctor (2013)', 2.99),
#  ('Back to the Future (1985)', 2.98),
#  ('Little Mermaid, The (1989)', 2.98),
#  ('Mean Girls (2004)', 2.98),
#  ('Special Day, A (Giornata particolare, Una) (1977)', 2.98),
#  ('Partly Cloudy (2009)', 2.98),
#  ('Chak De India! (2007)', 2.98),
#  ('Gurren Lagann: The Lights in the Sky are Stars (Gekijô ban Tengen toppa guren ragan: Ragan hen) (2009)',
#   2.98),
#  ('Louis Theroux: Gambling in Las Vegas (2007)', 2.98),
#  ('Legend of the Galactic Heroes: Overture to a New War (1993)', 2.98),
#  ('Western (2017)', 2.98),
#  ('1945 (2017)', 2.98),
#  ('So Long, My Son (2019)', 2.98),
#  ('Close (2022)', 2.98),
#  ('Spider-Man: Across the Spider-Verse (2023)', 2.98),
#  ('To Catch a Thief (1955)', 2.97),
#  ('Sting, The (1973)', 2.97),
#  ('Good Will Hunting (1997)', 2.97),
koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) (1983)', 2.9),
#  ("Ferris Bueller's Day Off (1986)", 2.9),
#  ('Trading Places (1983)', 2.9),
#  ('Heaven Knows, Mr. Allison (1957)', 2.9),
#  ('Sunday in the Country, A (Un dimanche à la campagne) (1984)', 2.9),
#  ('Rivers and Tides (2001)', 2.9),
#  ('Midnight (1939)', 2.9),
#  ('Day at the Races, A (1937)', 2.9),
#  ('Notti bianche, Le (White Nights) (1957)', 2.9),
#  ('English Surgeon, The (2007)', 2.9),
#  ('Swades: We, the People (Our Country) (2004)', 2.9),
#  ('3 Idiots (2009)', 2.9),
#  ('Hot Dog Program, A (1999)', 2.9),
#  ('Mildred Pierce (2011)', 2.9),
#  ('Welfare (1975)', 2.9),
#  ('Queen: Days of Our Lives (2011)', 2.9),
#  ('Prime Suspect 7: The Final Act (2006)', 2.9),
#  ('Aftershock (Tangshan dadizhen) (2010)', 2.9),
#  ('Cube of Sugar, A (Ye Habe Ghand) (2011)', 2.9),
#  ('Wildlike (2015)', 2.9),
#  ('The Fear of 13 (2015)', 2.9),
#  ('Daniel Tosh: Happy Thoughts (2011)', 2.9),
#  ('Wasp (2003)', 2.9),
#  ('Tashi and the Monk (2015)', 2.9),
#  ('Paddington 2 (2017)', 2.9),
#  ('Time Piece (1965)', 2.9),
#  ('Manila in the Claws of Light (1975)', 2.9),
#  ('The Shivering Truth (2018)', 2.9),
#  ('The Vampires of Poverty (1977)', 2.9),
#  ('Rear Window (1954)', 2.89),
#  ('Goldfinger (1964)', 2.89),
#  ('Murder by Death (1976)', 2.89),
#  ('Monkey Business (1931)', 2.89),
#  ('Harakiri (Seppuku) (1962)', 2.89),
#  ('Times of Harvey Milk, The (1984)', 2.89),
#  ('What Have I Done to Deserve This? (¿Qué he hecho yo para merecer esto!!) (1984)',
#   2.89),
#  ('Strangers in Good Company (1990)', 2.89),
#  ('Adrenaline Drive (Adorenarin doraibu) (1999)', 2.89),
#  ('Chorus, The (Choristes, Les) (2004)', 2.89),
#  ('Riding Giants (2004)', 2.89),
#  ('Trou, Le (Hole, The) (Night Watch, The) (1960)', 2.89),
#  ('Bleak Moments (1972)', 2.89),
#  ('Edvard Munch (1974)', 2.89),
#  ("Army of Shadows (L'armée des ombres) (1969)", 2.89),
#  ('Lonely Wife, The (Charulata) (1964)', 2.89),
#  ('Round-Up, The (Szegénylegények) (1966)', 2.89),
#  ('Girl Who Played with Fire, The (Flickan som lekte med elden) (2009)', 2.89),
#  ('How to Die in Oregon (2011)', 2.89),
#  ('The Hunger Games (2012)', 2.89),
#  ('Reel Injun (2009)', 2.89),
#  ('Teenage Paparazzo (2010)', 2.89),
#  ('Chef (2014)', 2.89),
#  ("Charlie's Country (2013)", 2.89),
#  ('The Imitation Game (2014)', 2.89),
#  ('Chris Rock: Bring the Pain (1996)', 2.89),
#  ('Winning Time: Reggie Miller vs. The New York Knicks (2010)', 2.89),
#  ('Puella Magi Madoka Magica the Movie Part II: Eternal (2012)', 2.89),
#  ('Concert, Le (2009)', 2.86),
#  ('Employment, The (Empleo, El) (2008)', 2.86),
#  ('S21: The Khmer Rouge Death Machine (S-21, la machine de mort Khmère rouge) (2003)',
#   2.86),
#  ('Separation, A (Jodaeiye Nader az Simin) (2011)', 2.86),
#  ('Prime Suspect: The Lost Child (1995)', 2.86),
#  ('56 Up (2012)', 2.86),
#  ('After Tiller (2013)', 2.86),
#  ('Cranford (2007)', 2.86),
#  ('The Dark Horse (2014)', 2.86),
#  ('Hera Pheri (2000)', 2.86),
#  ('Edifício Master (2002)', 2.86),
#  ('The Lost Room (2006)', 2.86),
#  ('Spotlight (2015)', 2.86),
#  ('Bridge To Terabithia (1985)', 2.86),
#  ('Family Nest (1979)', 2.86),
#  ('The Founder (2016)', 2.86),
#  ('Cosy Dens (1999)', 2.86),
#  ('Little Witch Academia: The Enchanted Parade (2015)', 2.86),
#  ('Chris Rock: Never Scared (2004)', 2.86),
#  ('Bully for Bugs (1953)', 2.86),
#  ('Icarus (2017)', 2.86),
#  ('Blue Planet II (2017)', 2.86),
#  ('Tom Segura: Disgraceful (2018)', 2.86),
#  ('3 Faces (2018)', 2.86),
#  ('The Painted Bird (2019)', 2.86),
#  ('Attack on Titan: Chronicle (2020)', 2.86),
#  ('Pretty Woman (1990)', 2.85),
#  ("Singin' in the Rain (1952)", 2.85),
#  ('North by Northwest (1959)', 2.85),
#  ('Robin Hood (1973)', 2.85),
#  ('Trouble in Paradise (1932)', 2.85),
#  ('House of Games (1987)', 2.85),
#  ('Coming to America (1988)', 2.85),
#  ('Moscow Does Not Believe in Tears (Moskva slezam ne verit) (1979)', 2.85),
#  ('In a Lonely Place (1950)', 2.85),
#  ('Those Magnificent Men in Their Flying Machines (1965)', 2.85),
#  ('Way Out West (1937)', 2.85),
#  ('Welcome Back, Mr. McDonald (Rajio no jikan) (1997)', 2.85),
#  ('Counterfeiters, The (Die Fälscher) (2007)', 2.85),
#  ("Bab'Aziz -The Prince Who Contemplated His Soul (2005)", 2.85),
#  ('Cherry Blossoms (Kirschblüten - Hanami) (2008)', 2.85),
#  ('Our Folks (Sami swoi) (1967)', 2.85),
#  ('Wild China (2008)', 2.85),
#  ('Wanda (1970)', 2.85),
#  ('Map For Saturday, A (2007)', 2.85),
#  ('Bleak House (2005)', 2.85),
#  ('The Hundred-Foot Journey (2014)', 2.85),
#  ('Wild Tales (2014)', 2.85),
#  ('Kennedys, The (2011)', 2.85),
#  ('National Gallery (2014)', 2.85),
#  ('The Perfect World of Kai (2007)', 2.85),
#  ('Heavenly Forest (2006)', 2.85),
#  ('Noodle (2007)', 2.85),
#  ('The Fatal Encounter (2014)', 2.85),
#  ('Seventeen Moments in Spring (1973)', 2.85),
#  ('Little Forest: Winter/Spring (2015)', 2.85),
#  ('Chris Rock: Kill the Messenger (2008)', 2.85),
#  ('The Store (1983)', 2.85),
#  ('One More Time With Feeling (2016)', 2.85),
#  ('Breadcrumb Trail (2014)', 2.85),
#  ('Roots (2016)', 2.84),
#  ('Jim Jefferies: Freedumb (2016)', 2.84),
#  ('Validation (2007)', 2.84),
#  ('Patriots Day (2016)', 2.84),
#  ('Sanctuary (2015)', 2.84),
#  ("Lumière\xa0! L'aventure commence (2017)", 2.84),
#  ('Ghost in the Shell: Stand Alone Complex - Individual Eleven (2006)', 2.84),
#  ('Kid with the Golden Arm (1979)', 2.84),
#  ('Knock Down the House (2019)', 2.84),
#  ('Secondhand Hearts (2017)', 2.84),
#  ('Untold: Malice at the Palace (2021)', 2.84),
#  ('Taylor Tomlinson: Look at You (2022)', 2.84),
#  ('Thirteen Lives (2022)', 2.84),
#  ('Mulan (1998)', 2.83),
#  ('Splendor in the Grass (1961)', 2.83),
#  ('Hatari! (1962)', 2.83),
#  ('Where Eagles Dare (1968)', 2.83),
#  ('Night at the Opera, A (1935)', 2.83),
#  ('Another Thin Man (1939)', 2.83),
#  ('Overboard (1987)', 2.83),
#  ('Enemy Below, The (1957)', 2.83),
#  ('Steamboat Bill, Jr. (1928)', 2.83),
#  ('As it is in Heaven (Så som i himmelen) (2004)', 2.83),
#  ("Hobson's Choice (1954)", 2.83),
#  ("Rory O'Shea Was Here (Inside I'm Dancing) (2004)", 2.83),
#  ("Elevator to the Gallows (a.k.a. Frantic) (Ascenseur pour l'échafaud) (1958)",
#   2.83),
#  ('Red and the White, The (Csillagosok, katonák) (1967)', 2.83),
#  ('Mirage (1965)', 2.83),
#  ("Nibelungen: Kriemhild's Revenge, Die (Die Nibelungen: Kriemhilds Rache) (1924)",
#   2.83),
#  ('God Grew Tired of Us (2006)', 2.83),
#  ('Equinox Flower (Higanbana) (1958)', 2.83),
#  ('Double Trouble (1984)', 2.83),
#  ('Phoebe in Wonderland (2008)', 2.83),
#  ('Secret in Their Eyes, The (El secreto de sus ojos) (2009)', 2.83),
#  ('Most Hated Family in America, The (2007)', 2.83),
#  ('Street of Shame (Akasen chitai) (1956)', 2.83),
#  ('Welcome to Dongmakgol (2005)', 2.83),
#  ('Maid, The (Nana, La) (2009)', 2.83),
#  ('Dream of Light (a.k.a. Quince Tree Sun, The) (Sol del membrillo, El) (1992)',
#   2.83),
#  ('Waiting Women (Kvinnors väntan) (1952)', 2.83),
#  ('Day the Universe Changed, The (1985)', 2.83),
#  ('Company: Original Cast Album (1970)', 2.83),
#  ("From the East (D'Est) (1993)", 2.83),
#  ('Mike Tyson:  Undisputed Truth (2013)', 2.83),
#  ('Captain America: The Winter Soldier (2014)', 2.83),
#  ('The Reunion (2013)', 2.83),
#  ('The Beaver Trilogy (2000)', 2.83),
#  ('Letter from Siberia (1957)', 2.83),
#  ('Plastic Bag (2009)', 2.83),
#  ('The Martian (2015)', 2.83),
#  ('Duck Amuck (1953)', 2.83),
#  ('The Skeleton Dance (1929)', 2.83),
#  ('The Adventures of Sherlock Holmes and Doctor Watson', 2.83),
#  ('Hornblower: The Even Chance (1998)', 2.83),
#  ('Ivy (2015)', 2.83),
#  ('The Battle of Chile - Part 1 (1975)', 2.83),
#  ('Survive and Advance (2013)', 2.83),
#  ('Twenty Years Later (1985)', 2.83),
#  ('Your Name. (2016)', 2.83),
#  ('After the Storm (2016)', 2.83),
#  ('Ethel & Ernest (2016)', 2.83),
#  ('John Wick: Chapter Two (2017)', 2.83),
#  ('Betting on Zero (2016)', 2.83),
#  ('Faces, Places (2017)', 2.83),
#  ('On the Trail of the Bremen Town Musicians (1973)', 2.83),
#  ('Us and Them (2018)', 2.83),
#  ('Raazi (2018)', 2.83),
#  ('Ford v. Ferrari (2019)', 2.83),
#  ('Daniel Sloss: X (2019)', 2.83),
#  ('James Acaster: Cold Lasagne Hate Myself 1999 (2020)', 2.83),
#  ('Joyland (2022)', 2.83),
#  ('Speed (1994)', 2.82),
#  ('In the Line of Fire (1993)', 2.82),
#  ('World of Apu, The (Apur Sansar) (1959)', 2.82),
#  ('And the Band Played On (1993)', 2.82),
#  ('Pixote (1981)', 2.82),
#  ('Rio Bravo (1959)', 2.82),
#  ('Point Break (1991)', 2.82),
#  ('Sleuth (1972)', 2.82),
#  ('Sorry, Wrong Number (1948)', 2.82),
#  ("My Father's Glory (La gloire de mon père) (1990)", 2.82),
#  ('Big Time Operators (Smallest Show on Earth, The) (1957)', 2.82),
#  ('Pillow Talk (1959)', 2.82),
#  ('I Was a Male War Bride (1949)', 2.82),
#  ('Miracle Worker, The (1962)', 2.82),
#  ('After the Thin Man (1936)', 2.82),
#  ('And Life Goes On (a.k.a. Life and Nothing More) (Zendegi va digar hich) (1992)',
#   2.82),
#  ('Tunnel, The (Tunnel, Der) (2001)', 2.82),
#  ('River, The (He liu) (1997)', 2.82),
#  ('Live and Become (Va, vis et deviens) (2005)', 2.82),
#  ('Gas, Inspector Palmu! (Kaasua, komisario Palmu!) (1961)', 2.82),
#  ('Cocaine Cowboys (2006)', 2.82),
#  ('Moment of Innocence, A (Nun va Goldoon) (1996)', 2.82),
#  ('Scum (1979)', 2.82),
#  ('Napoléon (1927)', 2.82),
#  ("Emperor's Naked Army Marches On, The (Yuki Yukite shingun) (1987)", 2.82),
#  ('Olympia Part Two: Festival of Beauty (Olympia 2. Teil - Fest der Schönheit) (1938)',
#   2.82),
#  ('Doulos, Le (1962)', 2.82),
#  ('Still Bill (2009)', 2.82),
#  ('Daughter from Danang (2002)', 2.82),
#  ("Geri's Game (1997)", 2.82),
#  ('How to Survive a Plague (2012)', 2.82),
#  ('Zero Dark Thirty (2012)', 2.82),
#  ('Sunny (Sseo-ni) (2011)', 2.82),
#  ('Jim Jefferies: Fully Functional (EPIX) (2012)', 2.82),
#  ('Stuck in Love (2012)', 2.82),
#  ('Lovecraft: Fear of the Unknown (2008)', 2.82),
#  ('Case of the Grinning Cat, The (Chats perchés) (2004)', 2.82),
#  ('Alive Inside (2014)', 2.82),
#  ("The Lumière Brothers' First Films (1996)", 2.82),
#  ('Nightingale (2015)', 2.82),
#  ('War Room (2015)', 2.82),
#  ('Justice: A Cross The Universe (2008)', 2.81),
#  ('The Choice (1970)', 2.81),
#  ('Waiting for the Hearse (1985)', 2.81),
#  ('Adventures of Mowgli: The Kidnapping (1968)', 2.81),
#  ("Fool's Day (2013)", 2.81),
#  ('Dust (2005)', 2.81),
#  ('The Defiant Ones (2017)', 2.81),
#  ('Bad Genius (2017)', 2.81),
#  ('Storm Boy (1976)', 2.81),
#  ('Shaadi Mein Zaroor Aana (2017)', 2.81),
#  ('Brigade Miscellaneous in the Mountains and at the Sea (1971)', 2.81),
#  ('Born in the USSR: 14 Up (1998)', 2.81),
#  ('Solitary (2016)', 2.81),
#  ('Пес Барбос и необычный кросс (1961)', 2.81),
#  ('Memorable (2019)', 2.81),
#  ('Crip Camp: A Disability Revolution (2020)', 2.81),
#  ('The Donut King (2020)', 2.81),
#  ('Infinity Train (2016)', 2.81),
#  ('The Year Earth Changed (2021)', 2.81),
#  ('Encanto (2021)', 2.81),
#  ('The Conviction (1991)', 2.81),
#  ('The Summit of the Gods (2021)', 2.81),
#  ('Still: A Michael J. Fox Movie (2023)', 2.81),
#  ('Aladdin (1992)', 2.8),
#  ('Sound of Music, The (1965)', 2.8),
#  ('Sneakers (1992)', 2.8),
#  ('Stripes (1981)', 2.8),
#  ('Metropolitan (1990)', 2.8),
#  ("Soldier's Story, A (1984)", 2.8),
#  ('Longest Day, The (1962)', 2.8),
#  ('Stalag 17 (1953)', 2.8),
#  ('Inherit the Wind (1960)', 2.8),
#  ('Hit the Bank (Vabank) (1981)', 2.8),
#  ('Music Box (1989)', 2.8),
#  ('Father of the Bride (1991)', 2.8),
#  ('Swing Time (1936)', 2.8),
#  ('Spy Who Came in from the Cold, The (1965)', 2.8),
#  ("That's Entertainment (1974)", 2.8),
#  ('Four Days of Naples, The (Le quattro giornate di Napoli) (1962)', 2.8),
#  ('Unknown Soldier, The (Tuntematon sotilas) (1985)', 2.8),
#  ('Heart in Winter, A (Un coeur en hiver) (1992)', 2.8),
#  ('Latcho Drom (1993)', 2.8),
#  ("O Auto da Compadecida (Dog's Will, A) (2000)", 2.8),
#  ('Taste of Tea, The (Cha no aji) (2004)', 2.8),
#  ('Interrogation (Przesluchanie) (1989)', 2.8),
#  ('Inside Man (2006)', 2.8),
#  ('Resurrection (1980)', 2.8),
#  ("Trial of Joan of Arc, The (Procès de Jeanne d'Arc) (1962)", 2.8),
#  ('Devil Wears Prada, The (2006)', 2.8),
#  ('Mrs. Palfrey at the Claremont (2005)', 2.8),
#  ('49 Up (2005)', 2.8),
#  ('Cave of the Yellow Dog, The (2005)', 2.8),
#  ('Taken (2008)', 2.8),
#  ('Repast (Meshi) (1951)', 2.8),
#  ('Crime Wave (1954)', 2.8),
#  ('News from a Personal War (Notícias de uma Guerra Particular) (1999)', 2.8),
#  ('Last Train Home (2009)', 2.8),
#  ('Hamlet (Gamlet) (1964)', 2.8),
#  ('Margin Call (2011)', 2.8),
#  ('Jack Reacher (2012)', 2.8),
#  ('Tie Xi Qu: West of the Tracks (Tiexi qu) (2003)', 2.8),
#  ('Urusei Yatsura Movie 2: Beautiful Dreamer (Urusei Yatsura 2: Byûtifuru dorîmâ) (1984)',
#   2.8),
#  ('Mark, The (1961)', 2.8),
#  ('Guardians of the Galaxy (2014)', 2.8),
#  ('Rob Roy, The Highland Rogue (1954)', 2.8),
#  ('Courier (1987)', 2.8),
#  ('Bleak Night (2010)', 2.8),
#  ('John Mulaney: New In Town (2012)', 2.8),
#  ('Scattered Clouds (Midaregumo) (1967)', 2.8),
#  ('Avengers: Infinity War - Part I (2018)', 2.8),
#  ('Avengers: Infinity War - Part II (2019)', 2.8),
#  ('Beastie Boys: Sabotage (1994)', 2.8),
#  ("Kevin Hart: I'm a Grown Little Man (2009)", 2.8),
#  ('Sarfarosh (1999)', 2.8),
#  ('Inside Out (2015)', 2.8),
#  ('Love & Mercy (2014)', 2.8),
#  ('A Frozen Flower (2008)', 2.8),
#  ('The Search for General Tso (2014)', 2.8),
#  ('Feast (2014)', 2.8),
#  ('Brancaleone alle crociate (1970)', 2.8),
#  ("George Carlin: Jammin' in New York (1992)", 2.8),
#  ('Next Goal Wins (2014)', 2.8),
#  ('Secrets of War (2014)', 2.8),
#  ('John Mulaney: The Comeback Kid (2015)', 2.8),
#  ('April and the Twisted World (2015)', 2.8),
#  ('The Resurrection of Jake the Snake (2015)', 2.8),
#  ('The Adversary (1970)', 2.8),
#  ('Lie Detector (2011)', 2.8),
#  ('Charles Darwin and the Tree of Life (2009)', 2.8),
#  ("George Carlin: Playin' with Your Head (1986)", 2.8),
#  ('To Walk Invisible (2016)', 2.8),
#  ('Investigation Held by Kolobki (1986)', 2.8),
#  ('Cat City (1986)', 2.8),
#  ('Three Men and a Leg (1997)', 2.8),
#  ('Wild Boys (2017)', 2.8),
#  ('Лабиринт (1971)', 2.8),
#  ('Microhabitat (2018)', 2.8),
#  ('John Wick: Chapter 3 – Parabellum (2019)', 2.8),
#  ('Game of Thrones - Conquest & Rebellion (2017)', 2.8),
#  ('Merry Christmas Mr. Bean (1992)', 2.8),
#  ('Ronny Chieng: Asian Comedian Destroys America! (2019)', 2.8),
#  ('The Mighty River (1994)', 2.8),
#  ('OPAL (2020)', 2.8),
#  ('Josee, the Tiger and the Fish (2020)', 2.8),
#  ('Ee Nagaraniki Emaindi (2018)', 2.8),
#  ('Theater Camp (2023)', 2.8),
#  ('American President, The (1995)', 2.79),
#  ('Clear and Present Danger (1994)', 2.79),
#  ('Gay Divorcee, The (1934)', 2.79),
#  ('When Harry Met Sally... (1989)', 2.79),
#  ('Playing by Heart (1998)', 2.79),
#  ('Castle, The (1997)', 2.79),
#  ('Mister Roberts (1955)', 2.79),
#  ('Mansfield Park (1999)', 2.79),
#  ('Cutting Edge, The (1992)', 2.79),
#  ('Big Country, The (1958)', 2.79),
#  ('Little Romance, A (1979)', 2.79),
#  ('Last Unicorn, The (1982)', 2.79),
#  ('To Have and Have Not (1944)', 2.79),
#  ("Grin Without a Cat, A (Fond de l'air est rouge, Le) (1977)", 2.78),
#  ("Sign 'o' the Times (1987)", 2.78),
#  ('Short Term 12 (2013)', 2.78),
#  ('Mystery Road (2013)', 2.78),
#  ('Labyrinth of Lies (2014)', 2.78),
#  ('Paddington (2014)', 2.78),
#  ('Han Gong-ju (2013)', 2.78),
#  ('La 317ème section (1965)', 2.78),
#  ('Cocaine Cowboys: Reloaded (2014)', 2.78),
#  ('Dreadnaught (1981)', 2.78),
#  ...]

# %% [markdown]
# ## Content based

# %%
merged2 = pd.merge (movies , tags , on = 'movieId')

# %%
tagged_df = merged2.groupby('movieId')['tag'] \
    .agg(lambda tags: '|'.join(str(tag) for tag in set(tags) if pd.notnull(tag))) \
    .reset_index()

# %%
tagged_df
# Out:
#        movieId                                                tag
# 0            1  low fantasy|surgical mask|lifting a female int...
# 1            2  based on a book|construction site|brother sist...
# 2            3  Funniest Movies|best friend|sequel fever|grun ...
# 3            4  revenge|divorce|chick flick|single mother|char...
# 4            5  sentimental|parent child relationship|growing ...
# ...        ...                                                ...
# 51318   292143  catalonia|village|replica|no narrator|seaside|...
# 51319   292349                              politically incorrect
# 51320   292371                                       Stephen King
# 51321   292597                            artificial intelligence
# 51322   292629        family relationships|documentary filmmaking
#
# [51323 rows x 2 columns]

# %%
combined = pd.merge(tagged_df , movies , on = 'movieId')
combined ['text_features'] = final ['tag'] + '|' + final ['genres']
combined
# Out:
#        movieId                                                tag  \
# 0            1  low fantasy|surgical mask|lifting a female int...
# 1            2  based on a book|construction site|brother sist...
# 2            3  Funniest Movies|best friend|sequel fever|grun ...
# 3            4  revenge|divorce|chick flick|single mother|char...
# 4            5  sentimental|parent child relationship|growing ...
# ...        ...                                                ...
# 51318   292143  catalonia|village|replica|no narrator|seaside|...
# 51319   292349                              politically incorrect
# 51320   292371                                       Stephen King
# 51321   292597                            artificial intelligence
# 51322   292629        family relationships|documentary filmmaking
#
#                                     title  \
# 0                        Toy Story (1995)
# 1                          Jumanji (1995)
# 2                 Grumpier Old Men (1995)
# 3                Waiting to Exhale (1995)
# 4      Father of the Bride Part II (1995)
# ...                                   ...
# 51318                La substància (2016)
# 51319               Totally Killer (2023)
# 51320     Pet Sematary: Bloodlines (2023)
# 51321                     The Mill (2023)
# 51322                    Gallivant (1997)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 51318                           (no genres listed)
# 51319                                Comedy|Horror
# 51320                               Fantasy|Horror
# 51321                                Horror|Sci-Fi
# 51322                                  Documentary
#
#                                            text_features
# 0      low fantasy|surgical mask|lifting a female int...
# 1      based on a book|construction site|brother sist...
# 2      Funniest Movies|best friend|sequel fever|grun ...
# 3      revenge|divorce|chick flick|single mother|char...
# 4      sentimental|parent child relationship|growing ...
# ...                                                  ...
# 51318  catalonia|village|replica|no narrator|seaside|...
# 51319                politically incorrect|Comedy|Horror
# 51320                        Stephen King|Fantasy|Horror
# 51321              artificial intelligence|Horror|Sci-Fi
# 51322  family relationships|documentary filmmaking|Do...
#
# [51323 rows x 5 columns]

# %%
final = combined [['movieId' , 'text_features']]
final
# Out:
#        movieId                                      text_features
# 0            1  low fantasy|surgical mask|lifting a female int...
# 1            2  based on a book|construction site|brother sist...
# 2            3  Funniest Movies|best friend|sequel fever|grun ...
# 3            4  revenge|divorce|chick flick|single mother|char...
# 4            5  sentimental|parent child relationship|growing ...
# ...        ...                                                ...
# 51318   292143  catalonia|village|replica|no narrator|seaside|...
# 51319   292349                politically incorrect|Comedy|Horror
# 51320   292371                        Stephen King|Fantasy|Horror
# 51321   292597              artificial intelligence|Horror|Sci-Fi
# 51322   292629  family relationships|documentary filmmaking|Do...
#
# [51323 rows x 2 columns]

# %%
import numpy as np
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()
# Out:
# True

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
final['embedding'] = final['text_features'].apply(
    lambda x: client.embeddings.create(model="text-embedding-3-small", input=x).data[0].embedding
)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22640\24426416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['embedding'] = final['text_features'].apply(

# %%
final
# Out:
#        movieId                                      text_features  \
# 0            1  low fantasy|surgical mask|lifting a female int...
# 1            2  based on a book|construction site|brother sist...
# 2            3  Funniest Movies|best friend|sequel fever|grun ...
# 3            4  revenge|divorce|chick flick|single mother|char...
# 4            5  sentimental|parent child relationship|growing ...
# ...        ...                                                ...
# 51318   292143  catalonia|village|replica|no narrator|seaside|...
# 51319   292349                politically incorrect|Comedy|Horror
# 51320   292371                        Stephen King|Fantasy|Horror
# 51321   292597              artificial intelligence|Horror|Sci-Fi
# 51322   292629  family relationships|documentary filmmaking|Do...
#
#                                                embedding
# 0      [0.012040429748594761, 0.013948115520179272, -...
# 1      [0.018080798909068108, 0.06331375241279602, -0...
# 2      [0.0014785799430683255, 0.04591622203588486, -...
# 3      [0.02682194672524929, 0.06319113820791245, -0....
# 4      [0.024181121960282326, 0.033560220152139664, -...
# ...                                                  ...
# 51318  [0.03421638906002045, 0.024409234523773193, -0...
# 51319  [-0.024666042998433113, 0.022995492443442345, ...
# 51320  [0.014681873843073845, 0.030048822984099388, -...
# 51321  [-0.02497914992272854, 0.030762914568185806, -...
# 51322  [0.0038790360558778048, 0.05217632278800011, -...
#
# [51323 rows x 3 columns]

# %%
final.to_csv('final.csv', index=False)

# %%
final = pd.read_csv ('final.csv')

# %%
final = final.merge(movies[['movieId', 'title']], on='movieId', how='left')
final
# Out:
#        movieId                                      text_features  \
# 0            1  low fantasy|surgical mask|lifting a female int...
# 1            2  based on a book|construction site|brother sist...
# 2            3  Funniest Movies|best friend|sequel fever|grun ...
# 3            4  revenge|divorce|chick flick|single mother|char...
# 4            5  sentimental|parent child relationship|growing ...
# ...        ...                                                ...
# 51318   292143  catalonia|village|replica|no narrator|seaside|...
# 51319   292349                politically incorrect|Comedy|Horror
# 51320   292371                        Stephen King|Fantasy|Horror
# 51321   292597              artificial intelligence|Horror|Sci-Fi
# 51322   292629  family relationships|documentary filmmaking|Do...
#
#                                                embedding  \
# 0      [0.012040429748594761, 0.013948115520179272, -...
# 1      [0.018080798909068108, 0.06331375241279602, -0...
# 2      [0.0014785799430683255, 0.04591622203588486, -...
# 3      [0.02682194672524929, 0.06319113820791245, -0....
# 4      [0.024181121960282326, 0.033560220152139664, -...
# ...                                                  ...
# 51318  [0.03421638906002045, 0.024409234523773193, -0...
# 51319  [-0.024666042998433113, 0.022995492443442345, ...
# 51320  [0.014681873843073845, 0.030048822984099388, -...
# 51321  [-0.02497914992272854, 0.030762914568185806, -...
# 51322  [0.0038790360558778048, 0.05217632278800011, -...
#
#                                     title
# 0                        Toy Story (1995)
# 1                          Jumanji (1995)
# 2                 Grumpier Old Men (1995)
# 3                Waiting to Exhale (1995)
# 4      Father of the Bride Part II (1995)
# ...                                   ...
# 51318                La substància (2016)
# 51319               Totally Killer (2023)
# 51320     Pet Sematary: Bloodlines (2023)
# 51321                     The Mill (2023)
# 51322                    Gallivant (1997)
#
# [51323 rows x 4 columns]

# %%
import numpy as np

import ast
final['embedding'] = final['embedding'].apply(ast.literal_eval)
emb_matrix = np.array(final['embedding'].to_list(), dtype=float)

# %%
def recommend(movie_id, n=5):
    # Find movie index
    idx = final.index[final['movieId'] == movie_id][0]
    
    # Compute cosine similarities
    target = emb_matrix[idx]
    norms = np.linalg.norm(emb_matrix, axis=1) * np.linalg.norm(target)
    sims = np.dot(emb_matrix, target) / norms
    
    # Get top-N similar movies (excluding itself)
    top_idx = np.argsort(sims)[::-1][1:n+1]
    return final.iloc[top_idx][['movieId', 'title' , 'text_features']]

# %%
# Example
recommend(1, 5)
# Out:
#        movieId                           title  \
# 2843      3114              Toy Story 2 (1999)
# 45251   201588              Toy Story 4 (2019)
# 14021    78499              Toy Story 3 (2010)
# 11397    56176  Alvin and the Chipmunks (2007)
# 1689      1920           Small Soldiers (1998)
#
#                                            text_features
# 2843   low fantasy|piggy bank|slinky dog|avi|mistaken...
# 45251  low fantasy|woody character|Disney|Pixar|piggy...
# 14021  garbage chute|piggy bank|brother sister relati...
# 11397  winter|live action cgi hybrid|family friendly|...
# 1689   attack|irreverence|live action and animation|b...

# %%
recommend(187593, 10)
# Out:
#        movieId                            title  \
# 22641   122904                  Deadpool (2016)
# 18530   104241                Kick-Ass 2 (2013)
# 36701   168252                     Logan (2017)
# 12607    68319  X-Men Origins: Wolverine (2009)
# 43985   192389                     Venom (2018)
# 46240   210271             6 Underground (2019)
# 18445   103772            Wolverine, The (2013)
# 18156   102125                Iron Man 3 (2013)
# 6931      7439             Punisher, The (2004)
# 22651   122924         X-Men: Apocalypse (2016)
#
#                                            text_features
# 22641  snow|construction site|character says i love y...
# 18530  needless violence|smoke grenade|kicked in the ...
# 36701  poisoning|lifting a female into the air|manhun...
# 12607  child in peril|set up|ororo munroe character|a...
# 43985  humor|manhunt|program|biohazard suit|specimen|...
# 46240  no story|air strike|afghanistan|close up of ey...
# 18445  snow|thrown off a balcony|stabbed in the stoma...
# 18156  child in peril|snow|child genius|toy gun|power...
# 6931   organized crime|character says i love you|crut...
# 22651  snow|no story|Oscar Isaac|group name in title|...
